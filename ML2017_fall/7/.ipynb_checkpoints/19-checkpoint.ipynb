# %% [markdown]
# ## PageRank
#
# #### История
#
# (Взято с <a href='https://ru.wikipedia.org/wiki/PageRank'>Википедии</a>)
#
# В 1996 году Сергей Брин и Ларри Пейдж, тогда ещё аспиранты Стэнфордского университета, начали работу над исследовательским проектом BackRub — поисковой системой по Интернету, использующей новую тогда идею о том, что веб-страница должна считаться тем «важнее», чем больше на неё ссылается других страниц, и чем более «важными», в свою очередь, являются эти страницы. Через некоторое время BackRub была переименована в Google. Первая статья с описанием применяющегося в ней метода ранжирования, названного PageRank, появилась в начале 1998 года, за ней следом вышла и статья с описанием архитектуры самой поисковой системы.
#
# Их система значительно превосходила все существовавшие тогда поисковые системы, и Брин с Пейджем, осознав её потенциал, основали в сентябре 1998 года компанию Google Inc., для дальнейшего её развития как коммерческого продукта.

# %% [markdown]
# #### Описание
#
# Введем понятие веб-графа. Ориентированный граф $G = (V, E)$ называется веб-графом, если
# * $V = \{url_i\}_{i=1}^n$ --- некоторое подмножество страниц в интернете, каждой из которых соответствует адрес $url_i$.
# * Множество $E$ состоит из тех и только тех пар $(url_i, url_j)$, для которых на странице с адресом $url_i$ есть
# ссылка на $url_j$.
#
# Рассмотрим следующую модель поведения пользователя. В начальный момент времени он выбирает некоторую страницу из $V$ в соответствии с некоторым распределением $\Pi^{(0)}$. Затем, находясь на некоторой странице, он может либо перейти по какой-то ссылке, которая размещена на этой странице, либо выбрать случайную страницу из $V$ и перейти на нее (damping factor). Считается, что если пользователь выбирает переход по ссылке, то он выбирает равновероятно любую ссылку с данной страницы и переходит по ней. Если же он выбирает переход не по ссылке, то он также выбирает равновероятно любую страницу из $V$ и переходит на ее (в частности может остаться на той же странице). Будем считать, что переход не по ссылке пользователь выбирает с некоторой вероятностью $p \in (0, 1)$. Соответственно, переход по ссылке он выбирает с вероятностью $1 - p$. Если же со страницы нет ни одной ссылки, то будем считать, что пользователь всегда выбирает переход не по ссылке.
#
# Описанная выше модель поведения пользователя называется моделью PageRank. Нетрудно понять, что этой модели соответствует некоторая марковская цепь. Опишите ее.

# %% [markdown]
# **Ответ.**
# * Множество состояний: множество страниц из V.
# * Начальное распределение: $\Pi^{(0)}$.
# * Переходные вероятности: $p_{ij}(n) = P(X_n = j|X_{n-1} = i) = p \cdot \frac{1}{|V|} + (1-p)\cdot I\{(i,j) \in E\}\cdot \frac{1}{deg\{i\}}$, если $deg\{i\} \ne 0$,
# и $p_{ij}(n) = P(X_n = j|X_{n-1} = i) = \frac{1}{|V|}$, иначе.

# %% [markdown]
# #### Вычисление
#
# Данная марковская цепь является эргодической. Почему?
#
# **Ответ**: данная марковская цепь является эргодической по эргодической теореме, так как множество состояний конечно и для любых $n_0$ и $j_0$: $p_{ij_0}^{n_0} > 0$ для любого $i \in V$.
#
# А это означает, что цепь имеет некоторое эргодическое распределение $\Pi$, которое является предельным и единственным стационарным. Данное распределение называется весом PageRank для нашего подмножества интернета.
#
# Как вычислить это распределение $\Pi$ для данного веб-графа? Обычно для этого используют степенной метод (power iteration), суть которого состоит в следующем. Выбирается некоторое начальное распределение $\Pi^{(0)}$. Далее производится несколько итераций по формуле $\Pi^{(k)} = \Pi^{(k - 1)} P$, где $P$ --- матрица переходных вероятностей цепи, до тех пор, пока $\left|\left|\Pi^{(k)} - \Pi^{(k - 1)}\right|\right| > \varepsilon$. Распределение $\Pi^{(k)}$ считается приближением распредения $\Pi$.
#
# Имеет ли смысл выполнять подобные итерации для разных начальных распределений $\Pi^{(0)}$ с точки зрения теории?
#
# **Ответ**: думаю, что подобные итерации с точки зрения теории не имеет смысл выполнять, так как теоретически невозможно определить, какое распределение будет лучше всех остальных приближать распределение $\Pi$.
#
# А с точки зрения практического применения, не обязательно при этом доводя до сходимости?
#
# **Ответ**: с точки зрения практического применения точно имеет смысл выпонять подобные итерации для разных начальных распределений. Возможно, нет необходимости доводить до сходимости $\leq \varepsilon$, но обнаружить, что распределения как-то сходятся нужно.
#
# Какая верхняя оценка на скорость сходимости?
#
# **Ответ**: на лекции в доказательстве эргодической теоремы было показано, что $max_{i \in V}\{p_{ij}(1 + k \cdot n_0)\} - min_{i \in V}\{p_{ij}(1 + k \cdot n_0)\} \leq (1-\varepsilon)^{k}$, то есть имеет место экспоненциальная сходимость.
#
# За ответы можно получить **1 балл**.

# %% [markdown]
# ## Часть 1
#
# За выполнение этой части можно получить **2 балла** за автоматическую проверку и **2 балла** за все остальное.

# %%
import numpy as np
from scipy.stats import bernoulli
import networkx
from bs4 import BeautifulSoup
from urllib.request import urlopen
from urllib.parse import urlparse, urlunparse
from time import sleep
from itertools import product
import matplotlib.pyplot as plt

# %matplotlib inline

# %% [markdown]
# Реализуйте вычисление весов PageRank power-методом.
#
# Реализовать может быть удобнее с помощью функции np.nan_to_num, которая в данном numpy.array заменит все вхождения nan на ноль. Это позволяет удобно производить поэлементное деление одного вектора на другой в случае, если во втором векторе есть нули.

# %%
def create_page_rank_markov_chain(links, damping_factor=0.15):
    ''' По веб-графу со списком ребер links строит матрицу 
    переходных вероятностей соответствующей марковской цепи.
    
        links --- список (list) пар вершин (tuple), 
                может быть передан в виде numpy.array, shape=(|E|, 2);
        damping_factor --- вероятность перехода не по ссылке (float);
        
        Возвращает prob_matrix --- numpy.matrix, shape=(|V|, |V|).
    '''

    links = np.array(links)
    N = links.max() + 1  # Число веб-страниц
    
    
    
    # Вероятность попасть из ребра i в ребро j, не по ссылке
    p_no_use_link = damping_factor / N
    # Просто массивчик этих вероятностей размера N
    v_map = np.vectorize(lambda x: p_no_use_link)
    list_p_no_use_link = v_map(range(N))
    
    # Массивчик вероятностей (1 - p) - будет использоваться для
    # подсчта переходных вероятностей
    v_map_p = np.vectorize(lambda x: 1 - damping_factor)
    list_p_using_link = v_map_p(range(N))
    
    
    
    # Преобразуем список рёбер в матрицу смежности
    adj_matrix = np.array(np.zeros(N * N))
    adj_matrix.shape = (N, N)
    # Пройдёмся по всем рёбрам из списка...
    for e in links:
        # и добавим каждое ребро
        adj_matrix[e[0]][e[1]] = 1
    
    # Создаём матрицу переходных вероятностей
    prob_matrix = adj_matrix
    
    
    
    # Заполним матрицу prob_matrix последовательно
    # для каждой из вершин
    for i in range(N):
        
        # Считаем степень i-й вершины
        deg_i = np.count_nonzero(adj_matrix[i])
        
        if(deg_i == 0):
            prob_matrix[i] = np.ones(N) / N
        
        else:
            a = np.nan_to_num(list_p_using_link / deg_i)
        
            # До этого момента в prob_matrix хранится индикатор наличия ребра
            prob_matrix[i] = prob_matrix[i] * a + list_p_no_use_link
    
    return np.matrix(prob_matrix)

# %%
l = np.array([[1,5],[2,4],[3,1],[0,2]])
print(l)
print(l.shape)
# Out:
# [[1 5]
#  [2 4]
#  [3 1]
#  [0 2]]
# (4, 2)

# %%
create_page_rank_markov_chain(l)
# Out:
# matrix([[ 0.025     ,  0.025     ,  0.875     ,  0.025     ,  0.025     ,
#           0.025     ],
#         [ 0.025     ,  0.025     ,  0.025     ,  0.025     ,  0.025     ,
#           0.875     ],
#         [ 0.025     ,  0.025     ,  0.025     ,  0.025     ,  0.875     ,
#           0.025     ],
#         [ 0.025     ,  0.875     ,  0.025     ,  0.025     ,  0.025     ,
#           0.025     ],
#         [ 0.16666667,  0.16666667,  0.16666667,  0.16666667,  0.16666667,
#           0.16666667],
#         [ 0.16666667,  0.16666667,  0.16666667,  0.16666667,  0.16666667,
#           0.16666667]])

# %%
def page_rank(links, start_distribution, damping_factor=0.15, 
              tolerance=10 ** (-7), return_trace=False):
    ''' Вычисляет веса PageRank для веб-графа со списком ребер links 
    степенным методом, начиная с начального распределения start_distribution, 
    доводя до сходимости с точностью tolerance.
    
        links --- список (list) пар вершин (tuple), 
                может быть передан в виде numpy.array, shape=(|E|, 2);
        start_distribution --- вектор размерности |V| в формате numpy.array;
        damping_factor --- вероятность перехода не по ссылке (float);
        tolerance --- точность вычисления предельного распределения;
        return_trace --- если указана, то возвращает список распределений во 
                            все моменты времени до сходимости
    
        Возвращает:
        1). если return_trace == False, то возвращает distribution --- 
        приближение предельного распределения цепи,
        которое соответствует весам PageRank.
        Имеет тип numpy.array размерности |V|.
        2). если return_trace == True, то возвращает также trace ---
        список распределений во все моменты времени до сходимости. 
        Имеет тип numpy.array размерности 
        (количество итераций) на |V|.
    '''
    
    prob_matrix = create_page_rank_markov_chain(links, 
                                                damping_factor=damping_factor)
    distribution = np.matrix(start_distribution)
    
    links = np.array(links)
    N = links.max() + 1  # Число веб-страниц
    
    # Это будет список распределений во все моменты времени до сходимости
    trace = np.array(distribution)
    # Счётчик количества итераций
    count_iterations = 1
    
    next_distribution = distribution * prob_matrix
    trace = np.append(trace, np.array(next_distribution).reshape(1, N))
    count_iterations += 1
    
    # Цикл, пока недостаточно хорошее приближение
    while(np.linalg.norm(next_distribution - distribution) > tolerance):      
        
        distribution = next_distribution
        next_distribution = distribution * prob_matrix
        
        trace = np.append(trace, np.array(next_distribution).reshape((1, N)))
        count_iterations += 1
    
    # Берём самое последнее распределение
    distribution = next_distribution
    
    trace = trace.reshape(count_iterations, 1, N)
    
    if return_trace:
        return np.array(distribution).ravel(), np.array(trace)
    else:
        return np.array(distribution).ravel()

# %%
st = np.array([0.1, 0.2, 0.3, 0.1, 0.1, 0.2])

# %%
page_rank(l, st, tolerance=0.005, return_trace=True)
# Out:
# (array([ 0.09189025,  0.1716111 ,  0.1716111 ,  0.09189025,  0.23649864,
#          0.23649864]),
#  array([[[ 0.1       ,  0.2       ,  0.3       ,  0.1       ,  0.1       ,
#            0.2       ]],
#
#         [[ 0.0675    ,  0.1525    ,  0.1525    ,  0.0675    ,  0.3225    ,
#            0.2375    ]],
#
#         [[ 0.10433333,  0.16170833,  0.16170833,  0.10433333,  0.23395833,
#            0.23395833]],
#
#         [[ 0.09128819,  0.17997153,  0.17997153,  0.09128819,  0.22874028,
#            0.22874028]],
#
#         [[ 0.08980975,  0.16740471,  0.16740471,  0.08980975,  0.24278554,
#            0.24278554]],
#
#         [[ 0.09378924,  0.17012752,  0.17012752,  0.09378924,  0.23608324,
#            0.23608324]],
#
#         [[ 0.09189025,  0.1716111 ,  0.1716111 ,  0.09189025,  0.23649864,
#            0.23649864]]]))

# %% [markdown]
# **Автоматическая проверка (2 балла) **
#
# Реализацию функций create_page_rank_markov_chain и page_rank скопируйте в файл с названием v[номер варианта].py и вышлите на почту. Будет проверяться только корректность выдаваемых значений. Проверки на время работы не будет.
#
# ----------
#
# Давайте посмотрим, как оно работает.
# Напишите для начала функцию для генерации случайного ориентированного графа $G(n, p)$. Случайный граф генерируется следующий образом. Берется множество $\{0, ..., n-1\}$, которое есть множество вершин этого графа. Ребро $(i, j)$ (пара упорядочена, возможно повторение) добавляется в граф независимо от других ребер с вероятностью $p$.

# %%
def random_graph(n, p):
    
    # Список рёбер
    edges = np.array([]).astype(int)
    
    # Количество рёбер в списке
    count_edges = 0
    
    for i in range(n):
        for j in range(n):
            # Генерируем рандомное число в интервале [0.0, 1.0)
            r = np.random.random_sample()
            if (r < p):
                count_edges += 1
                edges = np.append(edges, (i, j))
    
    edges = edges.reshape(count_edges, 2)
    
    return edges

# %% [markdown]
# Теперь сгенерируем случайный граф и нарисуем его.

# %%
N, p = 10, 0.2
edges = random_graph(N, p)

G = networkx.DiGraph()
G.add_edges_from(edges)
plt.axis('off')
networkx.draw_networkx(G, width=0.5)

# %% [markdown]
# Посчитаем его PageRank и изобразим так, чтобы размер вершины был пропорционален ее весу.

# %%
start_distribution = np.ones((1, N)) / N
pr_distribution = page_rank(edges, start_distribution)
size_const = 10 ** 4
plt.axis('off')
networkx.draw_networkx(G, width=0.5, node_size=size_const * pr_distribution,
                       node_color=pr_distribution)

# %% [markdown]
# Как мы уже отмечали выше, эргодическая теорема дает верхнюю оценку на скорость сходимости. Давайте посмотрим, насколько она является точной. Для этого при вычислении PageRank нужно установить флаг return_trace.

# %%
pr_distribution, pr_trace = page_rank(edges, start_distribution, 
                                      return_trace=True)
errors = np.abs(pr_trace - pr_trace[-1]).sum(axis=(1, 2))

plt.figure(figsize=(10, 4))
x = np.arange(len(errors))
plt.plot(x, errors, lw=2, label='error')
prob_matrix = create_page_rank_markov_chain(edges, 
                                            damping_factor=0.15)
# это из доказательства эргодической теоремы с лекции
eps = prob_matrix.min()
plt.plot(x, (1-eps) ** np.arange(0, len(pr_trace)), 
         lw=2, label='estimation')
plt.legend()
plt.xlabel('iterations')
plt.show()

# %% [markdown]
# **Выводы:** какая-то не очень точная оценка на скорость сходимости получилась. Всё-таки, на самом деле распределения сходятся существенно быстрее.

# %% [markdown]
# Проведите небольшое исследование. В ходе исследования выясните, как скорость сходимости (количество итераций до сходимости) зависит от $n$ и $p$, а так же начального распределения. Вычислите также веса PageRank для некоторых неслучайных графов. В каждом случае стройте графики. От чего зависит вес вершины?

# %% [markdown]
# <Исследования и выводы>

# %% [markdown]
# ## Часть 2
#
# За выполнение этой части можно получить **5 баллов** и больше. В этой части вам предстоит построить реальный веб-граф и посчитать его PageRank. Ниже определены вспомогательные функции.

# %%
def load_links(url, sleep_time=1, attempts=5, timeout=20):
    ''' Загружает страницу по ссылке url и выдает список ссылок, 
    на которые ссылается данная страница.
        url --- string, адрес страницы в интернете;
        sleep_time --- задержка перед загрузкой страницы;
        timeout --- время ожидания загрузки страницы;
        attempts --- число попыток загрузки страницы. 
        Попытка считается неудачной, если выбрасывается исключение.
    
        В случае, если за attempts попыток не удалось загрузить страницу,
        то последнее исключение пробрасывается дальше.
    '''
    
    sleep(sleep_time)
    parsed_url = urlparse(url)
    links = []

    # Попытки загрузить страницу
    for i in range(attempts):
        try:
            # Ловить исключения только из urlopen может быть недостаточно. 
            # Он может выдавать какой-то бред вместо исключения, 
            # из-за которого исключение сгенерирует BeautifulSoup
            soup = BeautifulSoup(urlopen(url, timeout=timeout), 'lxml')
            break
            
        except Exception as e:
            print(e)
            if i == attempts - 1:
                raise e

    for tag_a in soup('a'):  # Посмотр всех ссылочных тегов
        if 'href' in tag_a.attrs:
            link = list(urlparse(tag_a['href']))
            
            # Если ссылка является относительной,
            # то ее нужно перевести в абсолютную
            if link[0] == '': link[0] = parsed_url.scheme
            if link[1] == '': link[1] = parsed_url.netloc
            
            links.append(urlunparse(link))
            
    return links


def get_site(url):
    ''' По ссылке url возвращает адрес сайта. '''
    
    return urlparse(url).netloc

# %% [markdown]
# Код ниже загружает $N$ веб-страниц, начиная с некоторой стартовой страницы и переходя по ссылкам. Загрузка происходит методом обхода в ширину. Все собранные урлы страниц хранятся в urls. В links хранится список ссылок с одной страницы на другую. Особенность кода такова, что в urls хранятся все встреченные урлы, которых может быть сильно больше $N$. Аналогично, в links ребра могут ссылаться на страницы с номером больше $N$. Однако, все ребра из links начинаются только в первых $N$ страницах. Таким образом, для построения веб-графа нужно удалить все, что связано с вершинами, которые не входят в первые $N$.

# %%
urls = ['https://www.mathsisfun.com/']
site = get_site(urls[0])
links = []

N = 150
for i in range(N):
    try:
        # Загружаем страницу по урлу и извлекаем из него все ссылки
        # Не выставляйте sleep_time слишком маленьким, 
        # а то еще забанят где-нибудь
        links_from_url = load_links(urls[i], sleep_time=0.1)
        # Если мы хотим переходить по ссылкам только определенного сайта
        links_from_url = list(filter(lambda x: get_site(x) == site, 
                                     links_from_url))
        
        # Добавляем соответствующие вершины и ребра в веб-граф
        for j in range(len(links_from_url)):
            # Такая ссылка уже есть
            if links_from_url[j] in urls:
                links.append((i, urls.index(links_from_url[j])))
            
            # Новая ссылка
            else:
                # Префикс, с которого должна начинаться каждая ссылка
                pref = 'https://www.math'
                # Рёбра, ведущие из графа не добавляем
                if ((len(urls) < N) & (links_from_url[j][:len(pref)] == pref)):
                    links.append((i, len(urls)))
                    urls.append(links_from_url[j])
                    print(len(urls), links_from_url[j])
                
    except:
        pass  # Не загрузилась с 5 попытки, ну и ладно
# Out:
# 2 https://www.mathsisfun.com/about-ads.html
# 3 https://www.mathsisfun.com/links/index.html
# 4 https://www.mathsisfun.com/data/index.html
# 5 https://www.mathsisfun.com/geometry/index.html
# 6 https://www.mathsisfun.com/numbers/index.html
# 7 https://www.mathsisfun.com/puzzles/index.html
# 8 https://www.mathsisfun.com/money/index.html
# 9 https://www.mathsisfun.com/algebra/index.html
# 10 https://www.mathsisfun.com/calculus/index.html
# 11 https://www.mathsisfun.com/physics/index.html
# 12 https://www.mathsisfun.com/games/index.html
# 13 https://www.mathsisfun.com/definitions/index.html
# 14 https://www.mathsisfun.com/worksheets/index.php
# 15 https://www.mathsisfun.com/measure/index.html
# 16 https://www.mathsisfun.com/activity/index.html
# 17 https://www.mathsisfun.com/teacher-resources.html
# 18 https://www.mathsisfun.com/numbers/infinity.html
# 19 https://www.mathsisfun.com/games/connect4.html
# 20 https://www.mathsisfun.com/new.html
# 21 https://www.mathsisfun.com/tables.html
# 22 https://www.mathsisfun.com/timestable.html
# 23 https://www.mathsisfun.com/data/straight_line_graph.html
# 24 https://www.mathsisfun.com/math-tools.html
# 25 https://www.mathsisfun.com/links/external.html
# 26 https://www.mathsisfun.com/index.htm
# 27 https://www.mathsisfun.com/contact.php
# 28 https://www.mathsisfun.com/sphider/search.php
# 29 https://www.mathsisfun.com/aboutmathsisfun.html
# 30 https://www.mathsisfun.com/Privacy.htm
# 31 https://www.mathsisfun.com/../index.htm
# 32 https://www.mathsisfun.com/../numbers/index.html
# 33 https://www.mathsisfun.com/../algebra/index.html
# 34 https://www.mathsisfun.com/../geometry/index.html
# 35 https://www.mathsisfun.com/../data/index.html
# 36 https://www.mathsisfun.com/../measure/index.html
# 37 https://www.mathsisfun.com/../puzzles/index.html
# 38 https://www.mathsisfun.com/../games/index.html
# 39 https://www.mathsisfun.com/../definitions/index.html
# 40 https://www.mathsisfun.com/../worksheets/index.php
# 41 https://www.mathsisfun.com/../about-ads.html
# 42 https://www.mathsisfun.com/core-index.html
# 43 https://www.mathsisfun.com/index-curriculum.html
# 44 https://www.mathsisfun.com/a-kto2-numbers.html
# 45 https://www.mathsisfun.com/a-kto2-algebra.html
# 46 https://www.mathsisfun.com/a-kto2-geometry.html
# 47 https://www.mathsisfun.com/a-kto2-data.html
# 48 https://www.mathsisfun.com/a-kto2-measurement.html
# 49 https://www.mathsisfun.com/a-kto2-money.html
# 50 https://www.mathsisfun.com/b-3to6-numbers.html
# 51 https://www.mathsisfun.com/b-3to6-algebra.html
# 52 https://www.mathsisfun.com/b-3to6-geometry.html
# 53 https://www.mathsisfun.com/b-3to6-data.html
# 54 https://www.mathsisfun.com/b-3to6-measurement.html
# 55 https://www.mathsisfun.com/b-3to6-money.html
# 56 https://www.mathsisfun.com/c-7to9-numbers.html
# 57 https://www.mathsisfun.com/c-7to9-algebra.html
# 58 https://www.mathsisfun.com/c-7to9-geometry.html
# 59 https://www.mathsisfun.com/c-7to9-data.html
# 60 https://www.mathsisfun.com/c-7to9-measurement.html
# 61 https://www.mathsisfun.com/c-7to9-money.html
# 62 https://www.mathsisfun.com/d-10up-numbers.html
# 63 https://www.mathsisfun.com/d-10up-algebra.html
# 64 https://www.mathsisfun.com/d-10up-geometry.html
# 65 https://www.mathsisfun.com/d-10up-data.html
# 66 https://www.mathsisfun.com/d-10up-measurement.html
# 67 https://www.mathsisfun.com/d-10up-calculus.html
# 68 https://www.mathsisfun.com/../sphider/search.php
# 69 https://www.mathsisfun.com/index.html
# 70 https://www.mathsisfun.com/../aboutmathsisfun.html
# 71 https://www.mathsisfun.com/../contact.php
# 72 https://www.mathsisfun.com/../Privacy.htm
# 73 https://www.mathsisfun.com#data
# 74 https://www.mathsisfun.com#stats
# 75 https://www.mathsisfun.com/graphs-index.html
# 76 https://www.mathsisfun.com/data.html
# 77 https://www.mathsisfun.com/data-discrete-continuous.html
# 78 https://www.mathsisfun.com/analog-digital.html
# 79 https://www.mathsisfun.com/bar-graphs.html
# 80 https://www.mathsisfun.com/pie-charts.html
# 81 https://www.mathsisfun.com/dot-plots.html
# 82 https://www.mathsisfun.com/line-graphs.html
# 83 https://www.mathsisfun.com/scatter-xy-plots.html
# 84 https://www.mathsisfun.com/pictographs.html
# 85 https://www.mathsisfun.com/histograms.html
# 86 https://www.mathsisfun.com/frequency-distribution.html
# 87 https://www.mathsisfun.com/stem-leaf-plots.html
# 88 https://www.mathsisfun.com/cumulative-tables-graphs.html
# 89 https://www.mathsisfun.com/graph-paper-maker.html
# 90 https://www.mathsisfun.com/survey-conducting.html
# 91 https://www.mathsisfun.com/survey-questionnaire.html
# 92 https://www.mathsisfun.com/survey-results.html
# 93 https://www.mathsisfun.com/../accuracy-precision.html
# 94 https://www.mathsisfun.com/../activity/questions-asking.html
# 95 https://www.mathsisfun.com/../activity/questions-improving.html
# 96 https://www.mathsisfun.com/central-measures.html
# 97 https://www.mathsisfun.com/../mean.html
# 98 https://www.mathsisfun.com/../data/mean-machine.html
# 99 https://www.mathsisfun.com/../median.html
# 100 https://www.mathsisfun.com/../mode.html
# 101 https://www.mathsisfun.com/../activity/averages-brain-teaser.html
# 102 https://www.mathsisfun.com/mean-frequency-table.html
# 103 https://www.mathsisfun.com/frequency-grouped-mean-median-mode.html
# 104 https://www.mathsisfun.com/weighted-mean.html
# 105 https://www.mathsisfun.com/range.html
# 106 https://www.mathsisfun.com/quartiles.html
# 107 https://www.mathsisfun.com/percentiles.html
# 108 https://www.mathsisfun.com/mean-deviation.html
# 109 https://www.mathsisfun.com/../data/standard-deviation.html
# 110 https://www.mathsisfun.com/standard-deviation-calculator.html
# 111 https://www.mathsisfun.com/standard-deviation-formulas.html
# 112 https://www.mathsisfun.com/univariate-bivariate.html
# 113 https://www.mathsisfun.com/outliers.html
# 114 https://www.mathsisfun.com/correlation.html
# 115 https://www.mathsisfun.com/probability.html
# 116 https://www.mathsisfun.com/../probability_line.html
# 117 https://www.mathsisfun.com/spinner.php
# 118 https://www.mathsisfun.com/basic-counting-principle.html
# 119 https://www.mathsisfun.com/relative-frequency.html
# 120 https://www.mathsisfun.com/../activity/dice-experiment-1.html
# 121 https://www.mathsisfun.com/../activity/dice-experiment-2.html
# 122 https://www.mathsisfun.com/../activity/coin-grid.html
# 123 https://www.mathsisfun.com/../activity/buffons-needle.html
# 124 https://www.mathsisfun.com/random-words.html
# 125 https://www.mathsisfun.com/lottery.html
# 126 https://www.mathsisfun.com/probability-complement.html
# 127 https://www.mathsisfun.com/probability-events-types.html
# 128 https://www.mathsisfun.com/probability-events-independent.html
# 129 https://www.mathsisfun.com/probability-events-conditional.html
# 130 https://www.mathsisfun.com/probability-tree-diagrams.html
# 131 https://www.mathsisfun.com/probability-events-mutually-exclusive.html
# 132 https://www.mathsisfun.com/../combinatorics/combinations-permutations.html
# 133 https://www.mathsisfun.com/../combinatorics/combinations-permutations-calculator.html
# 134 https://www.mathsisfun.com/probability-false-negatives-positives.html
# 135 https://www.mathsisfun.com/bayes-theorem.html
# 136 https://www.mathsisfun.com/probability-shared-birthday.html
# 137 https://www.mathsisfun.com/confidence-interval.html
# 138 https://www.mathsisfun.com/confidence-interval-calculator.html
# 139 https://www.mathsisfun.com/chi-square-test.html
# 140 https://www.mathsisfun.com/chi-square-calculator.html
# 141 https://www.mathsisfun.com/random-variables.html
# 142 https://www.mathsisfun.com/random-variables-continuous.html
# 143 https://www.mathsisfun.com/random-variables-mean-variance.html
# 144 https://www.mathsisfun.com/quincunx.html
# 145 https://www.mathsisfun.com/quincunx-explained.html
# 146 https://www.mathsisfun.com/binomial-distribution.html
# 147 https://www.mathsisfun.com/standard-normal-distribution.html
# 148 https://www.mathsisfun.com/standard-normal-distribution-table.html
# 149 https://www.mathsisfun.com/skewness.html
# 150 https://www.mathsisfun.com/plane-geometry.html
# HTTP Error 400: Bad Request
# HTTP Error 400: Bad Request
# HTTP Error 400: Bad Request
# HTTP Error 400: Bad Request
# HTTP Error 400: Bad Request
# HTTP Error 400: Bad Request
# HTTP Error 400: Bad Request
# HTTP Error 400: Bad Request
# HTTP Error 400: Bad Request
# HTTP Error 400: Bad Request
# HTTP Error 400: Bad Request
# HTTP Error 400: Bad Request
# HTTP Error 400: Bad Request
# HTTP Error 400: Bad Request
# HTTP Error 400: Bad Request
# HTTP Error 400: Bad Request
# HTTP Error 400: Bad Request
# HTTP Error 400: Bad Request
# HTTP Error 400: Bad Request
# HTTP Error 400: Bad Request
# HTTP Error 400: Bad Request
# HTTP Error 400: Bad Request
# HTTP Error 400: Bad Request
# HTTP Error 400: Bad Request
# HTTP Error 400: Bad Request
# HTTP Error 400: Bad Request
# HTTP Error 400: Bad Request
# HTTP Error 400: Bad Request
# HTTP Error 400: Bad Request
# HTTP Error 400: Bad Request
# HTTP Error 400: Bad Request
# HTTP Error 400: Bad Request
# HTTP Error 400: Bad Request
# HTTP Error 400: Bad Request
# HTTP Error 400: Bad Request
# HTTP Error 400: Bad Request
# HTTP Error 400: Bad Request
# HTTP Error 400: Bad Request
# HTTP Error 400: Bad Request
# HTTP Error 400: Bad Request
# HTTP Error 400: Bad Request
# HTTP Error 400: Bad Request
# HTTP Error 400: Bad Request
# HTTP Error 400: Bad Request
# HTTP Error 400: Bad Request
# HTTP Error 400: Bad Request
# HTTP Error 400: Bad Request
# HTTP Error 400: Bad Request
# HTTP Error 400: Bad Request
# HTTP Error 400: Bad Request
# HTTP Error 400: Bad Request
# HTTP Error 400: Bad Request
# HTTP Error 400: Bad Request
# HTTP Error 400: Bad Request
# HTTP Error 400: Bad Request
# HTTP Error 400: Bad Request
# HTTP Error 400: Bad Request
# HTTP Error 400: Bad Request
# HTTP Error 400: Bad Request
# HTTP Error 400: Bad Request
# HTTP Error 400: Bad Request
# HTTP Error 400: Bad Request
# HTTP Error 400: Bad Request
# HTTP Error 400: Bad Request
# HTTP Error 400: Bad Request
# HTTP Error 400: Bad Request
# HTTP Error 400: Bad Request
# HTTP Error 400: Bad Request
# HTTP Error 400: Bad Request
# HTTP Error 400: Bad Request
# HTTP Error 400: Bad Request
# HTTP Error 400: Bad Request
# HTTP Error 400: Bad Request
# HTTP Error 400: Bad Request
# HTTP Error 400: Bad Request
# HTTP Error 400: Bad Request
# HTTP Error 400: Bad Request
# HTTP Error 400: Bad Request
# HTTP Error 400: Bad Request
# HTTP Error 400: Bad Request
# HTTP Error 400: Bad Request
# HTTP Error 400: Bad Request
# HTTP Error 400: Bad Request
# HTTP Error 400: Bad Request
# HTTP Error 400: Bad Request
# HTTP Error 400: Bad Request
# HTTP Error 400: Bad Request
# HTTP Error 400: Bad Request
# HTTP Error 400: Bad Request
# HTTP Error 400: Bad Request
# HTTP Error 400: Bad Request
# HTTP Error 400: Bad Request
# HTTP Error 400: Bad Request
# HTTP Error 400: Bad Request
# HTTP Error 400: Bad Request
# HTTP Error 400: Bad Request
# HTTP Error 400: Bad Request
# HTTP Error 400: Bad Request
# HTTP Error 400: Bad Request
# HTTP Error 400: Bad Request
# HTTP Error 400: Bad Request
# HTTP Error 400: Bad Request
# HTTP Error 400: Bad Request
# HTTP Error 400: Bad Request
# HTTP Error 400: Bad Request
# HTTP Error 400: Bad Request
# HTTP Error 400: Bad Request
# HTTP Error 400: Bad Request
# HTTP Error 400: Bad Request
# HTTP Error 400: Bad Request
# HTTP Error 400: Bad Request
# HTTP Error 400: Bad Request
# HTTP Error 400: Bad Request
# HTTP Error 400: Bad Request
# HTTP Error 400: Bad Request
# HTTP Error 400: Bad Request
# HTTP Error 400: Bad Request
# HTTP Error 400: Bad Request
# HTTP Error 400: Bad Request
# HTTP Error 400: Bad Request
# HTTP Error 400: Bad Request
# HTTP Error 400: Bad Request
# HTTP Error 400: Bad Request
# HTTP Error 400: Bad Request
# HTTP Error 400: Bad Request
# HTTP Error 400: Bad Request
# HTTP Error 400: Bad Request
# HTTP Error 400: Bad Request
# HTTP Error 400: Bad Request
# HTTP Error 400: Bad Request
# HTTP Error 400: Bad Request
# HTTP Error 400: Bad Request
# HTTP Error 400: Bad Request
# HTTP Error 400: Bad Request
# HTTP Error 400: Bad Request
# HTTP Error 400: Bad Request
# HTTP Error 400: Bad Request
# HTTP Error 400: Bad Request
# HTTP Error 400: Bad Request
# HTTP Error 400: Bad Request
# HTTP Error 400: Bad Request
# HTTP Error 400: Bad Request
# HTTP Error 400: Bad Request
# HTTP Error 400: Bad Request
# HTTP Error 400: Bad Request
# HTTP Error 400: Bad Request
# HTTP Error 400: Bad Request
# HTTP Error 400: Bad Request
# HTTP Error 400: Bad Request
# HTTP Error 400: Bad Request
# HTTP Error 400: Bad Request
# HTTP Error 400: Bad Request
# HTTP Error 400: Bad Request
# HTTP Error 400: Bad Request
# HTTP Error 400: Bad Request

# %% [markdown]
# Визуализируем построенный веб-граф скачанного сайта.

# %%
plt.figure(figsize=(20, 20))

G = networkx.DiGraph()
G.add_edges_from(links)
plt.axis('off')
networkx.draw_networkx(G, width=0.05)

# %% [markdown]
# Визуализируем полученный веб-граф, сделав размер вершин пропорционально весу PageRank.

# %%
plt.figure(figsize=(20, 20))

start_distribution = np.ones((1, N)) / N
pr_distribution = page_rank(links, start_distribution)
size_const = 10 ** 5
plt.axis('off')
networkx.draw_networkx(G, width=0.05, node_size=size_const * pr_distribution,
                       node_color=pr_distribution)

# %% [markdown]
# Построим гистограмму весов.

# %%
pl = plt.hist(pr_distribution, bins=100, normed=True)

# %% [markdown]
# Из гистограммы видно, что есть минимальное количество вершин с очень большим весом, затем следует несколько различных групп вершин с меньшим весом, и есть самая объёмная группа вершин с самым маленьким весом. Это же видно и из предыдущей визуализации графа.

# %%
pr_distribution, pr_trace = page_rank(links, start_distribution, 
                                      return_trace=True)
errors = np.abs(pr_trace - pr_trace[-1]).sum(axis=(1, 2))

plt.figure(figsize=(10, 4))
x = np.arange(len(errors))
plt.plot(x, errors, lw=2, label='error')
prob_matrix = create_page_rank_markov_chain(links, 
                                            damping_factor=0.15)
# это из доказательства эргодической теоремы с лекции
eps = prob_matrix.min()
plt.plot(x, (1-eps) ** np.arange(0, len(pr_trace)), 
         lw=2, label='estimation')
plt.legend()
plt.xlabel('iterations')
plt.show()

# %% [markdown]
# Скорость сходимости, как и следовало ожидать, экспоненциальная.

# %% [markdown]
# Теперь выберите какой-нибудь сайт с небольшим количеством страниц (не более 1000). Таким сайтом может быть, например, сайт <a href=http://ru.discrete-mathematics.org>кафедры Дискретной математики</a> (аккуратнее, если забанят, то лишитесь доступа к учебным материалам), <a href=http://yandexdataschool.ru>Школы анализа данных</a>, сайт магазина, больницы. Однако, советуем не выбирать сайты типа kremlin.ru, мало ли что.
#
# Постройте полный веб-граф для этого сайта и визуализируйте его. При отрисовке выставляйте width не более 0.1, иначе получится ужасно некрасиво.
#
# Посчитайте PageRank для этого веб-графа. Визуализируйте данный веб-граф, сделав размер вершин пропорционально весу PageRank (см. пример в части 1). Постройте гистограмму весов. Что можно сказать про скорость сходимости?
#
# Выделите небольшое количество (15-20) страниц с наибольшим весом и изобразите граф, индуцированный на этом множестве вершин. Что это за страницы? Почему именно они имеют большой вес?
#
# Как меняется вес PageRank для страниц в зависимости от начального приближения в случае, если не доводить итерационный процесс вычисления до сходимости? Какие выводы о поведении пользователя отсюда можно сделать?
#
# Для получения дополнительных баллов проведите аналогичные исследования для больших сайтов. Так же вы можете провести исследования, не ограничиваясь загрузкой только одного сайта.
